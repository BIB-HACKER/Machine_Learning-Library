# %% [markdown]
# # Human Activity Recognition

# %%
This project is to build a model that predicts the human activities such as Walking,
Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
This dataset is collected from 30 persons(referred as subjects in this dataset),
performing different activities with a smartphone to their waists.
The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone.
This experiment was video recorded to label the data manually.

# %% [markdown]
# ## Obtain the train data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
train = pd.read_csv('train.csv')
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0                     -0.710304                 -0.112754
# 1                     -0.861499                  0.053477
# 2                     -0.760104                 -0.118559
# 3                     -0.482845                 -0.036788
# 4                     -0.699205                  0.123320
#
#    angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                          0.030400                      -0.464761
# 1                         -0.007435                      -0.732626
# 2                          0.177899                       0.100699
# 3                         -0.012892                       0.640011
# 4                          0.122542                       0.693578
#
#    angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                          -0.018446          -0.841247           0.179941
# 1                           0.703511          -0.844788           0.180289
# 2                           0.808529          -0.848933           0.180637
# 3                          -0.485366          -0.848649           0.181935
# 4                          -0.615971          -0.847865           0.185151
#
#    angleZgravityMean  subject  Activity
# 0          -0.058627        1  STANDING
# 1          -0.054317        1  STANDING
# 2          -0.049118        1  STANDING
# 3          -0.047663        1  STANDING
# 4          -0.043892        1  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %% [markdown]
# ## Obtain the test data

# %%
test = pd.read_csv("test.csv")

# %%
test.shape
# Out:
# (2947, 563)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
# import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='Activity', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.Activity)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# C:\Users\P PAUL\AppData\Local\Temp\ipykernel_5860\71913079.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# C:\Users\P PAUL\AppData\Local\Temp\ipykernel_5860\71913079.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# C:\Users\P PAUL\AppData\Local\Temp\ipykernel_5860\71913079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('f_train.csv', index=False)
test.to_csv('f_test.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### "Without domain knowledge EDA has no meaning, without EDA a problem has no soul."

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# ### Static and Dynamic Activities

# %% [markdown]
#  *          In static activities (sit, stand, lie down) motion information will not be very useful.

# %% [markdown]
#  *               In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]


plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.title("Static Activities(closer view)")
sns.distplot(train[train["Activity"]=="SITTING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["Activity"]=="STANDING"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["Activity"]=="LAYING"]['tBodyAccMagmean'],hist = False, label = 'Laying')
plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)
plt.title("Dynamic Activities(closer view)")
sns.distplot(train[train["Activity"]=="WALKING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["Activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["Activity"]=="WALKING_UPSTAIRS"]['tBodyAccMagmean'],hist = False, label = 'Laying')
# Out:
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Dynamic Activities(closer view)'}, xlabel='tBodyAccMagmean', ylabel='Density'>

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='Activity', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
sns.boxplot(x='Activity', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20])
# Out:
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Indexed 7352 samples in 0.219s...
# [t-SNE] Computed neighbors for 7352 samples in 11.782s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.273s
# [t-SNE] Iteration 50: error = 114.0957184, gradient norm = 0.0213075 (50 iterations in 18.467s)
# [t-SNE] Iteration 100: error = 98.3223572, gradient norm = 0.0181748 (50 iterations in 7.981s)
# [t-SNE] Iteration 150: error = 93.5553436, gradient norm = 0.0094827 (50 iterations in 7.581s)
# [t-SNE] Iteration 200: error = 91.5031967, gradient norm = 0.0067648 (50 iterations in 7.340s)
# [t-SNE] Iteration 250: error = 90.3279419, gradient norm = 0.0056323 (50 iterations in 5.773s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.327942
# [t-SNE] Iteration 300: error = 3.5840194, gradient norm = 0.0014634 (50 iterations in 6.992s)
# [t-SNE] Iteration 350: error = 2.8231003, gradient norm = 0.0007573 (50 iterations in 6.740s)
# [t-SNE] Iteration 400: error = 2.4411635, gradient norm = 0.0005229 (50 iterations in 6.235s)
# [t-SNE] Iteration 450: error = 2.2226152, gradient norm = 0.0004040 (50 iterations in 5.722s)
# [t-SNE] Iteration 500: error = 2.0776336, gradient norm = 0.0003326 (50 iterations in 6.313s)
# [t-SNE] Iteration 550: error = 1.9720178, gradient norm = 0.0002851 (50 iterations in 6.025s)
# [t-SNE] Iteration 600: error = 1.8907652, gradient norm = 0.0002466 (50 iterations in 5.569s)
# [t-SNE] Iteration 650: error = 1.8256515, gradient norm = 0.0002210 (50 iterations in 5.539s)
# [t-SNE] Iteration 700: error = 1.7716386, gradient norm = 0.0001980 (50 iterations in 5.674s)
# [t-SNE] Iteration 750: error = 1.7260938, gradient norm = 0.0001819 (50 iterations in 6.304s)
# [t-SNE] Iteration 800: error = 1.6870574, gradient norm = 0.0001653 (50 iterations in 5.529s)
# [t-SNE] Iteration 850: error = 1.6531739, gradient norm = 0.0001542 (50 iterations in 5.553s)
# [t-SNE] Iteration 900: error = 1.6233456, gradient norm = 0.0001429 (50 iterations in 6.346s)
# [t-SNE] Iteration 950: error = 1.5966104, gradient norm = 0.0001333 (50 iterations in 5.855s)
# [t-SNE] Iteration 1000: error = 1.5728655, gradient norm = 0.0001263 (50 iterations in 5.605s)
# [t-SNE] KL divergence after 1000 iterations: 1.572865
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.174s...
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 11.732s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.834s
# [t-SNE] Iteration 50: error = 105.5745316, gradient norm = 0.0210450 (50 iterations in 45.084s)
# [t-SNE] Iteration 100: error = 90.5937042, gradient norm = 0.0102637 (50 iterations in 18.566s)
# [t-SNE] Iteration 150: error = 87.4113693, gradient norm = 0.0055164 (50 iterations in 15.451s)
# [t-SNE] Iteration 200: error = 86.1112366, gradient norm = 0.0039802 (50 iterations in 17.607s)
# [t-SNE] Iteration 250: error = 85.3962860, gradient norm = 0.0056038 (50 iterations in 17.504s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.396286
# [t-SNE] Iteration 300: error = 3.1443274, gradient norm = 0.0013869 (50 iterations in 16.153s)
# [t-SNE] Iteration 350: error = 2.5010190, gradient norm = 0.0006505 (50 iterations in 14.440s)
# [t-SNE] Iteration 400: error = 2.1798677, gradient norm = 0.0004299 (50 iterations in 17.156s)
# [t-SNE] Iteration 450: error = 1.9953468, gradient norm = 0.0003152 (50 iterations in 15.803s)
# [t-SNE] Iteration 500: error = 1.8771937, gradient norm = 0.0002515 (50 iterations in 14.298s)
# [t-SNE] Iteration 550: error = 1.7933867, gradient norm = 0.0002121 (50 iterations in 14.212s)
# [t-SNE] Iteration 600: error = 1.7305255, gradient norm = 0.0001840 (50 iterations in 14.377s)
# [t-SNE] Iteration 650: error = 1.6812813, gradient norm = 0.0001631 (50 iterations in 15.370s)
# [t-SNE] Iteration 700: error = 1.6414332, gradient norm = 0.0001440 (50 iterations in 30.892s)
# [t-SNE] Iteration 750: error = 1.6084301, gradient norm = 0.0001315 (50 iterations in 17.899s)
# [t-SNE] Iteration 800: error = 1.5804285, gradient norm = 0.0001212 (50 iterations in 20.386s)
# [t-SNE] Iteration 850: error = 1.5564904, gradient norm = 0.0001122 (50 iterations in 14.840s)
# [t-SNE] Iteration 900: error = 1.5361474, gradient norm = 0.0001037 (50 iterations in 14.775s)
# [t-SNE] Iteration 950: error = 1.5183911, gradient norm = 0.0000967 (50 iterations in 15.327s)
# [t-SNE] Iteration 1000: error = 1.5026956, gradient norm = 0.0000924 (50 iterations in 14.273s)
# [t-SNE] KL divergence after 1000 iterations: 1.502696
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.132s...
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 7352 samples in 7.895s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.717s
# [t-SNE] Iteration 50: error = 97.5245514, gradient norm = 0.0187246 (50 iterations in 12.435s)
# [t-SNE] Iteration 100: error = 84.0045242, gradient norm = 0.0068983 (50 iterations in 7.881s)
# [t-SNE] Iteration 150: error = 81.9729309, gradient norm = 0.0033692 (50 iterations in 7.470s)
# [t-SNE] Iteration 200: error = 81.1671906, gradient norm = 0.0025120 (50 iterations in 7.411s)
# [t-SNE] Iteration 250: error = 80.7689209, gradient norm = 0.0017352 (50 iterations in 7.567s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.768921
# [t-SNE] Iteration 300: error = 2.6998153, gradient norm = 0.0013043 (50 iterations in 7.120s)
# [t-SNE] Iteration 350: error = 2.1654172, gradient norm = 0.0005749 (50 iterations in 6.589s)
# [t-SNE] Iteration 400: error = 1.9162655, gradient norm = 0.0003473 (50 iterations in 6.601s)
# [t-SNE] Iteration 450: error = 1.7699991, gradient norm = 0.0002489 (50 iterations in 6.824s)
# [t-SNE] Iteration 500: error = 1.6759422, gradient norm = 0.0001935 (50 iterations in 6.844s)
# [t-SNE] Iteration 550: error = 1.6114751, gradient norm = 0.0001586 (50 iterations in 6.750s)
# [t-SNE] Iteration 600: error = 1.5648332, gradient norm = 0.0001338 (50 iterations in 7.283s)
# [t-SNE] Iteration 650: error = 1.5295571, gradient norm = 0.0001178 (50 iterations in 6.755s)
# [t-SNE] Iteration 700: error = 1.5020757, gradient norm = 0.0001047 (50 iterations in 7.016s)
# [t-SNE] Iteration 750: error = 1.4801233, gradient norm = 0.0000983 (50 iterations in 6.763s)
# [t-SNE] Iteration 800: error = 1.4623871, gradient norm = 0.0000900 (50 iterations in 6.877s)
# [t-SNE] Iteration 850: error = 1.4482191, gradient norm = 0.0000841 (50 iterations in 6.758s)
# [t-SNE] Iteration 900: error = 1.4366083, gradient norm = 0.0000818 (50 iterations in 8.979s)
# [t-SNE] Iteration 950: error = 1.4271402, gradient norm = 0.0000790 (50 iterations in 6.982s)
# [t-SNE] Iteration 1000: error = 1.4192140, gradient norm = 0.0000752 (50 iterations in 6.846s)
# [t-SNE] KL divergence after 1000 iterations: 1.419214
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\P PAUL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# ### Conclusion

# %% [markdown]
# -->As we can see all the features except standing and sitting can be seperated very easily

# %% [markdown]
# --> Model will probably be confused between standing and sitting
